# %%
import numpy as np

# Question One 
X = np.array([[25, 2],[5, 26],[3, 7]])
print(X)

# %%
np.shape
# Out:
# <function shape at 0x7a6f8c1e2830>

# %%
# what is the transpose of the matrix X
X = np.array([[25, 2], [5, 26], [3, 7]])
T_X = np.transpose(X)
print(T_X)

# %%
#generate a new n-darray of X scaled by 3
X_scaled = 3 * (X)
print(X_scaled)
# Out:
# [[225  18]
#  [ 45 234]
#  [ 27  63]]

# %%
#c Generate a new matrix multiplication
A = ([[3, 4],[5, 6],[7, 8]])
Trans_X = X * A
print(Trans_X)
# Out:
# [[ 75   8]
#  [ 25 156]
#  [ 21  56]]

# %%
#d the inverse of the matrix multiplication of A and X
P_inv = np.linalg.inv(Trans_X)
print(P_inv)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[30], line 3
#       1 # d the inverse of the matrix multiplication of A and X
#       2 # P = np.array([[75, 8],[25, 156],[21, 56]])
# ----> 3 P_inv = np.linalg.inv(Trans_X)
#       4 print(P_inv)
#
# File ~/Desktop/DataScience/env/lib/python3.10/site-packages/numpy/linalg/_linalg.py:603, in inv(a)
#     601 a, wrap = _makearray(a)
#     602 _assert_stacked_2d(a)
# --> 603 _assert_stacked_square(a)
#     604 t, result_t = _commonType(a)
#     606 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File ~/Desktop/DataScience/env/lib/python3.10/site-packages/numpy/linalg/_linalg.py:202, in _assert_stacked_square(*arrays)
#     200 m, n = a.shape[-2:]
#     201 if m != n:
# --> 202     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
# Question Two


# i)
sample = np.random.poisson(lam=5, size=1000)
## Our sample has an average of 5 which is also lamda and a size of 1000

# %%
mean = np.mean(sample)
print(mean)
# Out:
# 4.933

# %%
Variance = np.var(sample)
print(Variance)
# Out:
# 5.422511

# %%
import matplotlib.pyplot as plt
plt.hist(sample, bins=15, color="pink")
plt.title("A histogram To visualize the distribution")
plt.xlabel("Number of customers")
plt.ylabel("Frequecy of the occurance")
plt.show()
